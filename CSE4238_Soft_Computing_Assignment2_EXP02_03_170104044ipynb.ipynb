# %% [markdown]
# # Importing Libraries

# %%
import matplotlib.pyplot as plt
import warnings


import pandas as pd
import numpy as np
import os

import torch
import torchvision
from torchvision import models
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader, ConcatDataset
import torch.optim as optim

import torch.nn as nn
import torchvision.datasets as dsets

import zipfile  # unziping 
import glob  # finding image paths
import numpy as np  # creating numpy arrays
from skimage.io import imread  # reading images
from skimage.transform import resize  # resizing images

import PIL
import random
from pathlib import Path

#!pip install torchsummary
#from torchsummary import summary

# !pip install torchviz
from torchviz import make_dot, make_dot_from_trace


warnings.filterwarnings('ignore')
# Out:
# Collecting torchviz
#   Downloading torchviz-0.0.2.tar.gz (4.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchviz) (1.9.0+cu102)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (from torchviz) (0.10.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchviz) (3.7.4.3)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4151 sha256=85a836fa479fc9e024eee86e42d98005670960407f1367c5aefc433d2f1dca1b
#   Stored in directory: /root/.cache/pip/wheels/04/38/f5/dc4f85c3909051823df49901e72015d2d750bd26b086480ec2
# Successfully built torchviz
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Download and unzip

# %%
# !gdown --id '1xvdl_w2gVoOyIh7jAy2jBbXUkQOSVksY'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1xvdl_w2gVoOyIh7jAy2jBbXUkQOSVksY
# To: /content/CSE4238_SoftComputing_Assignment_2_training-a.zip
# 816MB [00:05, 145MB/s]

# %%
# !unzip '/content/CSE4238_SoftComputing_Assignment_2_training-a.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14702.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14703.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14704.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14705.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14706.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14707.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14708.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14709.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14710.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14711.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14712.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14713.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14714.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14715.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14716.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14717.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14718.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14719.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14720.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14721.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14722.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14723.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14724.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14725.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14726.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14727.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14728.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14729.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14730.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14731.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14732.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14733.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14734.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14735.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14736.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14737.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14738.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14739.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14740.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14741.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14742.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14743.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14744.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14745.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14746.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14747.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14748.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14749.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14750.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14751.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14752.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14753.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14754.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14755.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14756.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14757.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14758.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14759.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14760.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14761.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14762.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14763.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14764.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14765.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14766.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14767.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14768.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14769.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14770.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14771.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14772.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14773.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14774.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14775.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14776.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14777.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14778.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14779.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14780.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14781.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14782.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14783.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14784.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14785.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14786.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14787.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14788.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14789.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14790.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14791.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14792.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14793.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14794.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14795.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14796.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14797.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14798.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14799.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14800.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14801.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14802.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14803.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14804.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14805.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14806.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14807.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14808.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14809.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14810.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14811.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14812.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14813.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14814.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14815.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14816.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14817.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14818.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14819.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14820.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14821.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14822.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14823.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14824.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14825.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14826.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14827.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14828.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14829.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14830.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14831.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14832.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14833.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14834.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14835.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14836.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14837.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14838.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14839.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14840.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14841.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14842.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14843.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14844.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14845.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14846.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14847.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14848.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14849.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14850.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14851.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14852.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14853.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14854.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14855.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14856.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14857.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14858.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14859.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14860.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14861.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14862.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14863.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14864.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14865.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14866.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14867.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14868.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14869.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14870.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14871.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14872.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14873.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14874.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14875.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14876.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14877.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14878.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14879.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14880.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14881.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14882.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a14883.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a
png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a19700.png
#   inflating: CSE4238_SoftComputing_Assignment_2_training-a/a19701.png

# %%
# !rm '/content/CSE4238_SoftComputing_Assignment_2_training-a.zip'
print("removed")
# Out:
# removed

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/CSE4238_SoftComputing_Assignment_2_training-a.csv")
df = df.loc[:, ['filename','digit']]

# %% [markdown]
# ## Data Preprocessing

# %%
class processDataset(Dataset):

    def __init__(self, root, image_dir, csv_file, transform=None):
        self.root = root
        self.image_dir = image_dir
        self.image_files = csv_file.iloc[:, 0]
        self.data = csv_file.iloc[:, 1]
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        image_name = os.path.join(self.image_dir, self.image_files[index])
        image = PIL.Image.open(image_name)
        label = self.data[index]
        if self.transform:
            image = self.transform(image)
        return (image, label)

# %%
root = Path(os.getcwd())
image_dir = root/'CSE4238_SoftComputing_Assignment_2_training-a'
csv_file = df
mean = [0.5,]
std = [0.5, ]
transform_img = transforms.Compose([
                            transforms.Grayscale(),
                            transforms.Resize(28),
                            # transforms.CenterCrop(28),
                            transforms.ToTensor(),
                            transforms.Normalize(mean, std)
])

# %%
dset = processDataset(root, image_dir, csv_file, transform= transform_img)
dset_size = len(dset)
test_perc = 20
test_size = int(dset_size * (test_perc/100))
train_size = dset_size - test_size
train_dataset, test_dataset = torch.utils.data.random_split(dset, [train_size, test_size])

# %%
print(dset_size, test_size, train_size)
# Out:
# 19702 3940 15762

# %% [markdown]
# # Model 2

# %% [markdown]
# Here the Hyperparameters are
#
#
# 1. Number of hidden
# layers
#
# 2. Number of nodes in
# hidden layers
#
# 3. Iteration
#
# 4. Learning rate
#
# 5. Batch size
#
# 6. Activation function of hidden layers

# %% [markdown]
# ## Model 2 Exp 1

# %%
#device
#device = 'cuda' if torch.cuda.is_available() else 'cpu'
#print('Using {} device'.format(device))

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Hyperparameters
batch_size = 64
num_iters = 40000
input_dim = 28*28
output_dim = 10
learning_rate = 0.01

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

num_epochs = num_iters / (len(train_dataset) / batch_size)
num_epochs = int(num_epochs)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False) 

class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes):
        super().__init__()
        self.linear_1 = nn.Linear(input_size, 684)
        self.relu_1 = nn.ReLU()

        self.linear_2 = nn.Linear(684, 500)
        self.relu_2 = nn.ReLU()

        self.linear_3 = nn.Linear(500, 300)
        self.relu_3 = nn.ReLU()

        self.linear_4 = nn.Linear(300, 150)
        self.relu_4 = nn.ReLU()

        self.linear_out = nn.Linear(150, num_classes)
        self.relu_out = nn.ReLU()

    def forward(self, x):
        
        out  = self.linear_1(x)
        out = self.relu_1(out)
        
        out  = self.linear_2(out)
        out = self.relu_2(out)

        out  = self.linear_3(out)
        out = self.relu_3(out)

        out  = self.linear_4(out)
        out = self.relu_4(out)
        
        probas  = self.linear_out(out)
        probas  = self.relu_out(out)
        return probas

# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)


iter = 0
test_loss_min = 9999999
iter_data,train_loss_data, test_loss_data, acc_data = [], [], [], []

for epoch in range(num_epochs):
    train_loss = 0.0
    test_loss = 0.0
    for i, (images, labels) in enumerate(train_loader):

        images = images.view(-1, input_dim).to(device)
        labels = labels.to(device)

        # Clear gradients w.r.t. parameters
        optimizer.zero_grad()

        # Forward pass to get output/logits
        outputs = model(images) 

        # Calculate Loss: softmax --> cross entropy loss
        loss = criterion(outputs, labels)

        # Getting gradients w.r.t. parameters
        loss.backward()

        # Updating parameters
        optimizer.step()

        train_loss += loss.item() * images.size(0)

        
        iter += 1

        if iter % 500 == 0:
            # Calculate Accuracy         
            correct = 0
            total = 0
            # Iterate through test dataset
            for images, labels in test_loader:
               
                images = images.view(-1, input_dim).to(device)

                # Forward pass only to get logits/output
                outputs = model(images)
                test_loss += loss.item() * images.size(0)

                # Get predictions from the maximum value
                _, predicted = torch.max(outputs, 1)

                # Total number of labels
                total += labels.size(0)


                # Total correct predictions
                if torch.cuda.is_available():
                    correct += (predicted.cpu() == labels.cpu()).sum() 
                else:
                    correct += (predicted == labels).sum()

            accuracy = 100 * correct.item() / total

            train_loss = train_loss / len(train_loader.dataset)
            test_loss = test_loss / len(test_loader.dataset)
            train_loss_data.append(train_loss)
            test_loss_data.append(test_loss)
            accuracy = 100 * correct.item() / total
            acc_data.append(accuracy)
            iter_data.append(iter)

            # Print Loss
            print('Iteration: {}. Train_Loss: {}. Valid_Loss: {}. Accuracy: {}'.format(iter, train_loss, test_loss, accuracy))

            if test_loss <= test_loss_min:
              print('***Validation loss decreased ({:.4f} --> {:.4f}). Saving model ...***'.format(test_loss_min,test_loss))
              torch.save(model.state_dict(), 'EXP_02_trial_2.pt')
              test_loss_min = test_loss

#3hrs 23 mins--->76% accuracy
# Out:
# Iteration: 500. Train_Loss: 0.0906649636611193. Valid_Loss: 3.6232595443725586. Accuracy: 9.619289340101522
# ***Validation loss decreased (9999999.0000 --> 3.6233). Saving model ...***
# Iteration: 1000. Train_Loss: 0.17536827525940057. Valid_Loss: 3.5911641120910645. Accuracy: 10.152284263959391
# ***Validation loss decreased (3.6233 --> 3.5912). Saving model ...***
# Iteration: 1500. Train_Loss: 0.2745878647735406. Valid_Loss: 4.062124252319336. Accuracy: 9.644670050761421
# Iteration: 2000. Train_Loss: 0.36529718754089147. Valid_Loss: 3.454375743865967. Accuracy: 9.720812182741117
# ***Validation loss decreased (3.5912 --> 3.4544). Saving model ...***
# Iteration: 2500. Train_Loss: 0.4454169620068118. Valid_Loss: 4.380027770996094. Accuracy: 14.086294416243655
# Iteration: 3000. Train_Loss: 0.5472736162607508. Valid_Loss: 3.353555679321289. Accuracy: 14.51776649746193
# ***Validation loss decreased (3.4544 --> 3.3536). Saving model ...***
# Iteration: 3500. Train_Loss: 0.634488461420267. Valid_Loss: 4.025447368621826. Accuracy: 16.6497461928934
# Iteration: 4000. Train_Loss: 0.7110593137727778. Valid_Loss: 4.033345699310303. Accuracy: 32.20812182741117
# Iteration: 4500. Train_Loss: 0.6548454866480697. Valid_Loss: 3.1645164489746094. Accuracy: 19.923857868020306
# Iteration: 38000. Train_Loss: 0.3843257063280098. Valid_Loss: 0.3341585695743561. Accuracy: 88.4771573604061
# Iteration: 38500. Train_Loss: 0.32877986713376023. Valid_Loss: 0.3969700038433075. Accuracy: 78.85786802030456
# Iteration: 39000. Train_Loss: 0.31130043965066057. Valid_Loss: 0.08693311363458633. Accuracy: 89.44162436548223
# ***Validation loss decreased (0.1441 --> 0.0869). Saving model ...***
# Iteration: 39500. Train_Loss: 0.45325418345109264. Valid_Loss: 0.5504530072212219. Accuracy: 89.08629441624366
# Iteration: 40000. Train_Loss: 0.31197950162646765. Valid_Loss: 0.1627456396818161. Accuracy: 90.1015228426396

# %%
'''
# Hyperparameters
batch_size = 50
num_iters = 65000
input_dim = 28*28
output_dim = 10
learning_rate = 0.0001
'''

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

num_epochs = num_iters / (len(train_dataset) / batch_size)
num_epochs = int(num_epochs)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False) 

class DeepNeuralNetworkModel(nn.Module):
    def __init__(self, input_size, num_classes):
        super().__init__()
        self.linear_1 = nn.Linear(input_size, 600)
        self.relu_1 = nn.ReLU()

        self.linear_2 = nn.Linear(600, 300)
        self.relu_2 = nn.ReLU()

        self.linear_3 = nn.Linear(300, 120)
        self.relu_3 = nn.ReLU()

        self.linear_out = nn.Linear(120, num_classes)
        self.relu_out = nn.ReLU()

    def forward(self, x):
        
        out  = self.linear_1(x)
        out = self.relu_1(out)
        
        out  = self.linear_2(out)
        out = self.relu_2(out)

        out  = self.linear_3(out)
        out = self.relu_3(out)
        
        probas  = self.linear_out(out)
        probas  = self.relu_out(out)
        return probas

# INSTANTIATE MODEL CLASS

model = DeepNeuralNetworkModel(input_size = input_dim,
                               num_classes = output_dim)
# To enable GPU
model.to(device)

# INSTANTIATE LOSS & OPTIMIZER CLASS
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

iter = 0
test_loss_min = 9999999
iter_data,train_loss_data, test_loss_data, acc_data = [], [], [], []

for epoch in range(num_epochs):
    train_loss = 0.0
    test_loss = 0.0
    for i, (images, labels) in enumerate(train_loader):

        images = images.view(-1, input_dim).to(device)
        labels = labels.to(device)

        # Clear gradients w.r.t. parameters
        optimizer.zero_grad()

        # Forward pass to get output/logits
        outputs = model(images) 

        # Calculate Loss: softmax --> cross entropy loss
        loss = criterion(outputs, labels)

        # Getting gradients w.r.t. parameters
        loss.backward()

        # Updating parameters
        optimizer.step()

        train_loss += loss.item() * images.size(0)

        iter += 1

        if iter % 500 == 0:
            # Calculate Accuracy         
            correct = 0
            total = 0
            # Iterate through test dataset
            for images, labels in test_loader:
               
                images = images.view(-1, input_dim).to(device)
                labels = labels.to(device)

                # Forward pass only to get logits/output
                outputs = model(images)

                loss = criterion(outputs, labels)

                test_loss += loss.item() * images.size(0)

                # Get predictions from the maximum value
                _, predicted = torch.max(outputs, 1)

                # Total number of labels
                total += labels.size(0)


                # Total correct predictions
                if torch.cuda.is_available():
                    correct += (predicted.cpu() == labels.cpu()).sum() 
                else:
                    correct += (predicted == labels).sum()

            train_loss = train_loss / len(train_loader.dataset)
            test_loss = test_loss / len(test_loader.dataset)
            train_loss_data.append(train_loss)
            test_loss_data.append(test_loss)
            accuracy = 100 * correct.item() / total
            acc_data.append(accuracy)
            iter_data.append(iter)

            # Print Loss
            print('Iteration: {}. Train_Loss: {}. Valid_Loss: {}. Accuracy: {}'.format(iter, train_loss, test_loss, accuracy))

            if test_loss <= test_loss_min:
              print('***Validation loss decreased ({:.4f} --> {:.4f}). Saving model ...***'.format(test_loss_min,test_loss))
              torch.save(model.state_dict(), 'EXP_02_trial_2.pt')
              test_loss_min = test_loss
# Out:
# Iteration: 500. Train_Loss: 2.238340618918653. Valid_Loss: 3.8218332262813743. Accuracy: 13.83248730964467
# ***Validation loss decreased (9999999.0000 --> 3.8218). Saving model ...***
# Iteration: 1000. Train_Loss: 0.6186939181296478. Valid_Loss: 3.7632010842337826. Accuracy: 17.741116751269036
# ***Validation loss decreased (3.8218 --> 3.7632). Saving model ...***
# Iteration: 1500. Train_Loss: 2.7279049698856634. Valid_Loss: 3.6127676128736. Accuracy: 29.517766497461928
# ***Validation loss decreased (3.7632 --> 3.6128). Saving model ...***
# Iteration: 2000. Train_Loss: 1.1567208393623556. Valid_Loss: 3.4748524191415853. Accuracy: 31.34517766497462
# ***Validation loss decreased (3.6128 --> 3.4749). Saving model ...***
# Iteration: 2500. Train_Loss: 3.135844067168287. Valid_Loss: 3.3998414150954503. Accuracy: 33.3248730964467
# ***Validation loss decreased (3.4749 --> 3.3998). Saving model ...***
# Iteration: 3000. Train_Loss: 1.6554472803721618. Valid_Loss: 3.342372185082605. Accuracy: 36.54822335025381
# ***Validation loss decreased (3.3998 --> 3.3424). Saving model ...***
# Iteration: 3500. Train_Loss: 0.26134243699412496. Valid_Loss: 3.3097984004141714. Accuracy: 36.015228426395936
# ***Validation loss decreased (3.3424 --> 3.3098). Saving model ...***
# Iteration: 4000. Train_Loss: 2.162005434392022. Valid_Loss: 3.2721913556762154. Accuracy: 37.63959390862944
# ***Validation loss decreased (3.3098 --> 3.2722). Saving model ...***
# Iteration: 4500. Train_Loss: 0.7653056327317393. Valid_Loss: 3.290262547846373. Accuracy: 34.67005076142132
# Iteration: 5000. Train_Loss: 2.6777927690374566. Valid_Loss: 3.222736564384499. Accuracy: 37.30964467005076
# ***Validation loss decreased (3.2722 --> 3.2227). Saving model ...***
# Iteration: 5500. Train_Loss: 1.286035055376645. Valid_Loss: 3.24906883263951. Accuracy: 38.07106598984772
# Iteration: 6000. Train_Loss: 3.147431863562859. Valid_Loss: 3.1717518797985793. Accuracy: 39.18781725888325
# ***Validation loss decreased (3.2227 --> 3.1718). Saving model ...***
# Iteration: 6500. Train_Loss: 1.792794747365306. Valid_Loss: 3.1604804938214683. Accuracy: 39.23857868020305
# ***Validation loss decreased (3.1718 --> 3.1605). Saving model ...***
# Iteration: 57500. Train_Loss: 1.5979044906092603. Valid_Loss: 1.767915021041928. Accuracy: 65.22842639593908
# Iteration: 58000. Train_Loss: 0.891444280265234. Valid_Loss: 1.8137930359332088. Accuracy: 63.90862944162436
# Iteration: 58500. Train_Loss: 0.21377475964147236. Valid_Loss: 1.7830749414293898. Accuracy: 64.46700507614213
# Iteration: 59000. Train_Loss: 1.15418242551306. Valid_Loss: 1.757609486579895. Accuracy: 65.20304568527919
# ***Validation loss decreased (1.7578 --> 1.7576). Saving model ...***
# Iteration: 59500. Train_Loss: 0.4745257086461003. Valid_Loss: 1.7481696330351273. Accuracy: 65.35532994923858
# ***Validation loss decreased (1.7576 --> 1.7482). Saving model ...***
# Iteration: 60000. Train_Loss: 1.4288519467894247. Valid_Loss: 1.8674004365344943. Accuracy: 63.24873096446701
# Iteration: 60500. Train_Loss: 0.7534569491666672. Valid_Loss: 1.7292000182389002. Accuracy: 66.16751269035532
# ***Validation loss decreased (1.7482 --> 1.7292). Saving model ...***
# Iteration: 61000. Train_Loss: 0.059927762681617154. Valid_Loss: 1.8104286847380817. Accuracy: 63.857868020304565
# Iteration: 61500. Train_Loss: 0.9947682806129853. Valid_Loss: 1.750304305311387. Accuracy: 65.63451776649747
# Iteration: 62000. Train_Loss: 0.33174025620653036. Valid_Loss: 1.7495701185942907. Accuracy: 65.35532994923858
# Iteration: 62500. Train_Loss: 1.2843745316879471. Valid_Loss: 1.7558846277028777. Accuracy: 65.0761421319797
# Iteration: 63000. Train_Loss: 0.5941384330026965. Valid_Loss: 1.7416409780531366. Accuracy: 65.91370558375634
# Iteration: 63500. Train_Loss: 1.556605370633721. Valid_Loss: 1.7554349820625963. Accuracy: 65.30456852791878
# Iteration: 64000. Train_Loss: 0.8673393479414269. Valid_Loss: 1.7230701674967248. Accuracy: 66.11675126903553
# ***Validation loss decreased (1.7292 --> 1.7231). Saving model ...***
# Iteration: 64500. Train_Loss: 0.18900479252092459. Valid_Loss: 1.7301979833447994. Accuracy: 66.24365482233503
# Iteration: 65000. Train_Loss: 1.1271211895947528. Valid_Loss: 1.7370866180071372. Accuracy: 65.48223350253807

# %% [markdown]
# ## Loss Graph

# %%
plt.plot(iter_data, train_loss_data, 'c', label='Training loss')
plt.plot(iter_data, test_loss_data, 'm', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Accuracy Graph

# %%
plt.plot(iter_data, acc_data, 'g', label='Accuracy')
plt.title('Accuracy Graph')
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Model Visualization

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model1 = nn.Sequential()
model1.add_module('W0', nn.Linear(784, 600))
model1.add_module('ReLU', nn.ReLU())
model1.add_module('W1', nn.Linear(600, 300))
model1.add_module('ReLU', nn.ReLU())
model1.add_module('W2', nn.Linear(300, 120))
model1.add_module('ReLU', nn.ReLU())
model1.add_module('W6', nn.Linear(120, 10))

xx = torch.randn(32,784).to(device='cpu')
yy = model1(xx)

make_dot(yy.mean(), params=dict(model1.named_parameters()))
# make_dot(yy.mean(), params=dict(model1.named_parameters())).render("model1", format="png")
